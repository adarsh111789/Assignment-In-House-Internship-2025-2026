# %%
Assignment-1
18-06-2026

# %%
# 1) Print statement with multiple objects
print("Hello", "Welcome", "to", "Python")
# Out:
# Hello Welcome to Python

# %%
# 2) Print statement with separator
print("2026", "06", "09", sep="-")
# Out:
# 2026-06-09

# %%
# 3) Print statement with end
print("Hello", end=" ")
print("World")
# Out:
# Hello World

# %%
# 4) Using input to ask user name and display greeting message

name = input("Enter your name: ")

print("Hello", name, "! Welcome to Python Programming.")
# Out:
# Enter your name:  Adarsh
# Hello Adarsh ! Welcome to Python Programming.
